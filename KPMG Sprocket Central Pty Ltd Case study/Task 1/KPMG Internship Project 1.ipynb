# %%
# Analysis of Sheet 1:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Reading the csv file and putting it into 'df' object.
Trans1= pd.read_excel(r"C:\Users\Vicky Yewle\Downloads\KPMG INTERNSHIP\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 
                     "Transactions",skiprows=1)
Trans1.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
# ...

# %%
Trans1.shape
# Out:
# (20000, 26)

# %%
Trans1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
# there are unnamed columns inside the dataset of Transactions

Trans1.drop(Trans1.columns[Trans1.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)

# %%
Trans1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
# The datatype of column (product_first_sold_date)  is not correct make it correct
Trans1['product_first_sold_date']=pd.to_datetime(Trans1['product_first_sold_date']).dt.date

# %%
# count of Null Values are as given below 
Trans1.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
Trans1.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %%
Trans1['order_status'].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
for cols in Trans1.columns:
    print(Trans1[cols].value_counts())
    print('-------------------------------')
# Out:
# 2049     1
# 17714    1
# 15677    1
# 13628    1
# 3387     1
#         ..
# 4759     1
# 6806     1
# 661      1
# 2708     1
# 2047     1
# Name: transaction_id, Length: 20000, dtype: int64
# -------------------------------
# 0      1378
# 3       354
# 1       311
# 35      268
# 38      267
#        ...
# 71      137
# 16      136
# 8       136
# 100     130
# 47      121
# Name: product_id, Length: 101, dtype: int64
# -------------------------------
# 1068    14
# 2476    14
# 2183    14
# 2548    13
# 3232    13
#         ..
# 2876     1
# 822      1
# 2477     1
# 1846     1
# 1544     1
# Name: customer_id, Length: 3494, dtype: int64
# -------------------------------
# 2017-08-18    82
# 2017-02-14    82
# 2017-10-15    76
# 2017-01-31    73
# 2017-12-19    71
#               ..
# 2017-01-12    38
# 2017-12-07    37
# 2017-03-29    36
# 2017-09-25    35
# 2017-10-19    32
# Name: transaction_date, Length: 364, dtype: int64
# -------------------------------
# 1.0    9829
# ...

# %%
# there is no duplicate values

dup=Trans1.duplicated()
Trans1[dup].sum()
# Out:
# transaction_id             0.0
# product_id                 0.0
# customer_id                0.0
# online_order               0.0
# order_status               0.0
# brand                      0.0
# product_line               0.0
# product_class              0.0
# product_size               0.0
# list_price                 0.0
# standard_cost              0.0
# product_first_sold_date    0.0
# dtype: float64

# %%
# Reading the csv file and putting it into 'df' object.
Trans2= pd.read_excel(r"C:\Users\Vicky Yewle\Downloads\KPMG INTERNSHIP\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 
                     "NewCustomerList",skiprows=1)
Trans2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# 0      Mass Customer                  N      Yes  ...    QLD  Australia
# ...

# %%
Trans2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
# clearly here it is not mentioned the names of columns no 16 to 20  so we have to drop these columns

# %%
cols=['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20']
Trans2.drop(
    axis=1,
    columns=cols,
    inplace=True
)

# %%
Trans2.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
# there are many missing values as per given below
Trans2.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %%
Trans2.duplicated().sum()
# Out:
# 0

# %%
cols=Trans2.columns
cols
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
# here there are unknown and unspecified values of U that we are not able to find 
Trans2['gender'].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %%
# lets replace the valueof U by 
Trans2['gender'].str.replace('U','Unspecified')
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3      Female
# 4      Female
#         ...
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: gender, Length: 1000, dtype: object

# %%
Trans3= pd.read_excel(r"C:\Users\Vicky Yewle\Downloads\KPMG INTERNSHIP\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 
                     "CustomerDemographic",skiprows=1)
Trans3.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator  ...  \
# 0                Health      Mass Customer                  N  ...
# 1    Financial Services      Mass Customer                  N  ...
# ...

# %%
Trans3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 26 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
# therr are around 14 columns which ave no name

cols=['Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
       'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
       'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
       'Unnamed: 25']

# %%
Trans3=Trans3.drop(columns=cols)

# %%
#here there are many values of Gender while there are only 2 available in the real world
Trans3['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# Femal        1
# F            1
# M            1
# Name: gender, dtype: int64

# %%
 Trans3['gender']=Trans3['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')

# %%
Trans3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
# there is one columns of default who have na values and we dont know much about values and also data is not known
Trans3.default
# Out:
# 0                                                      "'
# 1                            <script>alert('hi')</script>
# 2                                     2018-02-01 00:00:00
# 3       () { _; } >_[$($())] { touch /tmp/blns.shellsh...
# 4                                                     NIL
#                               ...
# 3995                                                 -100
# 3996                                             â¦testâ§
# 3997                                                  NaN
# 3998                               Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ
# 3999                                                  0/0
# Name: default, Length: 4000, dtype: object

# %%
Trans3.drop(axis=1,columns='default').head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
# There are some na values in Dataset of Customerdemographic.
Trans3.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
Trans4= pd.read_excel(r"C:\Users\Vicky Yewle\Downloads\KPMG INTERNSHIP\KPMG_VI_New_raw_data_update_final.xlsx", sheet_name= 
                     "CustomerAddress",skiprows=1)
Trans4.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0                  10         NaN         NaN         NaN         NaN  ...
# 1                  10         NaN         NaN         NaN         NaN  ...
# 2                   9         NaN         NaN         NaN         NaN  ...
# 3                   4         NaN         NaN         NaN         NaN  ...
# 4                   9         NaN         NaN         NaN         NaN  ...
#
#    Unnamed: 16  Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  \
# ...

# %%
Trans4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 26 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
#  6   Unnamed: 6          0 non-null      float64
#  7   Unnamed: 7          0 non-null      float64
#  8   Unnamed: 8          0 non-null      float64
#  9   Unnamed: 9          0 non-null      float64
#  10  Unnamed: 10         0 non-null      float64
#  11  Unnamed: 11         0 non-null      float64
#  12  Unnamed: 12         0 non-null      float64
#  13  Unnamed: 13         0 non-null      float64
#  14  Unnamed: 14         0 non-null      float64
# ...

# %%
# in the above sheet there are some unnamed columns around 20 and there are no NA values in the sheet so
